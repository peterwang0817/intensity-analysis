# %%
#import 
import numpy as np
from matplotlib import pyplot as plt
from skimage import io
from scipy.optimize import curve_fit
from scipy import optimize
import math

# %%
def singlePMTimage(start,end,step,PMT):
    #plot all image for single PMT level, input starting power angle, ending power angle, angle step and PMT level
    Power = np.arange (start,end+step, step)
    powstep = np.size(Power)
    fig, axs = plt.subplots(nrows=1, ncols = powstep, figsize=(9, 6),subplot_kw={'xticks': [], 'yticks': []})
    for ax, i in zip(axs.flat, Power):
        a = np.array(io.imread(""+str(int(i))+"_" + str(PMT) +".tif"))
        ax.imshow(a,cmap="plasma")
    plt.tight_layout()
    plt.show()

# %%
singlePMTimage(6,12,2,550)
